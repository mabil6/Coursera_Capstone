# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# #### Mary Bilan
# Artist

# %% [markdown]
# *I am interested in data science because I want to learn something new.*

# %% [markdown]
# ### My code will import two libraries, declare a variable and display a histogram.

# %%
import numpy as np
x=np.array([4,2,2,5,6,6,8,2,2,1,9,7,2,1,4,3,7])
import seaborn as ans
ans.distplot(x)

# %% [markdown]
# ~~STRIKE THROUGH TEST~~
#
#
# - Mercury
# - Venus
# - Earth
# - Mars
# - Jupiter
#
# Here is my hyperlink:[Duck Duck Go](https://duckduckgo.com)
